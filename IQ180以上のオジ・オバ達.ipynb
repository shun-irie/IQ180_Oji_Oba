# %% [markdown]
# <a href="https://colab.research.google.com/github/shun-irie/IQ180_Oji_Oba/blob/main/IQ180%E4%BB%A5%E4%B8%8A%E3%81%AE%E3%82%AA%E3%82%B8%E3%83%BB%E3%82%AA%E3%83%90%E9%81%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

IQs = np.random.normal(loc=100, scale=15, size=10000000)
count, Xs = np.histogram(IQs, range=(0, 200), bins=200)
plt.plot(Xs[1:], count, 'k-')
plt.axvline(x=180)

idx_180 = np.where(Xs >= 180)[0][0]
above_180 = np.sum(count[idx_180:])

plt.title(f'IQ >= 180: {above_180}')
plt.show()
